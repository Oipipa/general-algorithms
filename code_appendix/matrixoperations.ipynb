# %%
import math
import cmath

# %%
class MatrixLogger:
    def __init__(self):
        self.logs = []
        self.step = 0
    def log(self, action, data):
        self.logs.append({'step': self.step, 'action': action, 'data': data})
        self.step += 1
    def clear(self):
        self.logs = []
        self.step = 0
    def print_table(self):
        print("{:<10} {:<30} {:<50}".format("Step", "Action", "Data"))
        print("-" * 90)
        for entry in self.logs:
            print("{:<10} {:<30} {:<50}".format(entry['step'], entry['action'], str(entry['data'])))
    def get_logs(self):
        return self.logs

# %% [markdown]
# # Matrix Computations

# %% [markdown]
# ## Basic Operations

# %%
def matrix_add(A, B):
    return [[A[i][j] + B[i][j] for j in range(len(A[0]))] for i in range(len(A))]

def matrix_sub(A, B):
    return [[A[i][j] - B[i][j] for j in range(len(A[0]))] for i in range(len(A))]

def split_matrix(matrix):
    n = len(matrix)
    mid = n // 2
    A11 = [row[:mid] for row in matrix[:mid]]
    A12 = [row[mid:] for row in matrix[:mid]]
    A21 = [row[:mid] for row in matrix[mid:]]
    A22 = [row[mid:] for row in matrix[mid:]]
    return A11, A12, A21, A22

def join_quadrants(C11, C12, C21, C22):
    top = [C11[i] + C12[i] for i in range(len(C11))]
    bottom = [C21[i] + C22[i] for i in range(len(C21))]
    return top + bottom

# %% [markdown]
# ## Strassen's Algorithm

# %%
def strassen(A, B, logger=None):
    n = len(A)
    if n == 1:
        result = [[A[0][0] * B[0][0]]]
        if logger:
            logger.log("Base Case", f"Multiplying {A[0][0]} and {B[0][0]} = {result[0][0]}")
        return result

    A11, A12, A21, A22 = split_matrix(A)
    B11, B12, B21, B22 = split_matrix(B)
    if logger:
        logger.log("Split", f"A-> {A11}, {A12}, {A21}, {A22}; B-> {B11}, {B12}, {B21}, {B22}")

    M1 = strassen(matrix_add(A11, A22), matrix_add(B11, B22), logger)
    if logger: logger.log("M1", f"M1 = {M1}")
    M2 = strassen(matrix_add(A21, A22), B11, logger)
    if logger: logger.log("M2", f"M2 = {M2}")
    M3 = strassen(A11, matrix_sub(B12, B22), logger)
    if logger: logger.log("M3", f"M3 = {M3}")
    M4 = strassen(A22, matrix_sub(B21, B11), logger)
    if logger: logger.log("M4", f"M4 = {M4}")
    M5 = strassen(matrix_add(A11, A12), B22, logger)
    if logger: logger.log("M5", f"M5 = {M5}")
    M6 = strassen(matrix_sub(A21, A11), matrix_add(B11, B12), logger)
    if logger: logger.log("M6", f"M6 = {M6}")
    M7 = strassen(matrix_sub(A12, A22), matrix_add(B21, B22), logger)
    if logger: logger.log("M7", f"M7 = {M7}")

    C11 = matrix_add(matrix_sub(matrix_add(M1, M4), M5), M7)
    C12 = matrix_add(M3, M5)
    C21 = matrix_add(M2, M4)
    C22 = matrix_add(matrix_sub(matrix_add(M1, M3), M2), M6)
    if logger:
        logger.log("Combine Quadrants", f"C11 = {C11}, C12 = {C12}, C21 = {C21}, C22 = {C22}")

    C = join_quadrants(C11, C12, C21, C22)
    if logger:
        logger.log("Result", f"Result = {C}")
    return C

# %%
A = [
    [1, 2],
    [3, 4]
]

B = [
    [5, 6],
    [7, 8]
]

logger = MatrixLogger()

result = strassen(A, B, logger)

print("Matrix A:")
for row in A:
    print(row)
print("\nMatrix B:")
for row in B:
    print(row)
print("\nStrassen's Multiplication Result (A x B):")
for row in result:
    print(row)

print("\nLogger Details:")
logger.print_table()
# Out:
# Matrix A:
# [1, 2]
# [3, 4]
#
# Matrix B:
# [5, 6]
# [7, 8]
#
# Strassen's Multiplication Result (A x B):
# [19, 22]
# [43, 50]
#
# Logger Details:
# Step       Action                         Data
# ------------------------------------------------------------------------------------------
# 0          Split                          A-> [[1]], [[2]], [[3]], [[4]]; B-> [[5]], [[6]], [[7]], [[8]]
# 1          Base Case                      Multiplying 5 and 13 = 65
# 2          M1                             M1 = [[65]]
# 3          Base Case                      Multiplying 7 and 5 = 35
# 4          M2                             M2 = [[35]]
# 5          Base Case                      Multiplying 1 and -2 = -2
# 6          M3                             M3 = [[-2]]
# 7          Base Case                      Multiplying 4 and 2 = 8
# 8          M4                             M4 = [[8]]
# 9          Base Case                      Multiplying 3 and 8 = 24
# 10         M5                             M5 = [[24]]
# 11         Base Case                      Multiplying 2 and 11 = 22
# 12         M6                             M6 = [[22]]
# 13         Base Case                      Multiplying -2 and 15 = -30
# 14         M7                             M7 = [[-30]]
# 15         Combine Quadrants              C11 = [[19]], C12 = [[22]], C21 = [[43]], C22 = [[50]]
# 16         Result                         Result = [[19, 22], [43, 50]]

# %% [markdown]
# ## Matrix Inversion

# %%
def invert_matrix(A, logger=None):
    n = len(A)
    aug = [row[:] + [1 if i == j else 0 for j in range(n)] for i, row in enumerate(A)]
    if logger:
        logger.log("Init", f"Augmented matrix: {aug}")

    for i in range(n):
        pivot = aug[i][i]
        if abs(pivot) < 1e-12:
            for j in range(i+1, n):
                if abs(aug[j][i]) > 1e-12:
                    aug[i], aug[j] = aug[j], aug[i]
                    if logger:
                        logger.log("Swap", f"Swapped rows {i} and {j}")
                    pivot = aug[i][i]
                    break
        if abs(pivot) < 1e-12:
            raise ValueError("Matrix is singular and cannot be inverted.")
        for j in range(2 * n):
            aug[i][j] /= pivot
        if logger:
            logger.log("Normalize", f"Row {i} normalized, new row: {aug[i]}")
        for k in range(n):
            if k != i:
                factor = aug[k][i]
                for j in range(2 * n):
                    aug[k][j] -= factor * aug[i][j]
                if logger:
                    logger.log("Eliminate", f"Eliminated entry at row {k}, column {i}, new row: {aug[k]}")

    inverse = [row[n:] for row in aug]
    if logger:
        logger.log("Result", f"Inverse matrix: {inverse}")
    return inverse

# %%
A = [
    [4, 7, 2],
    [3, 6, 1],
    [2, 5, 1]
]

logger = MatrixLogger()
inv_A = invert_matrix(A, logger)
print("Matrix A:")
for row in A:
    print(row)
print("\nInverse of Matrix A:")
for row in inv_A:
    print(row)
print("\nLogger Details:")
logger.print_table()
# Out:
# Matrix A:
# [4, 7, 2]
# [3, 6, 1]
# [2, 5, 1]
#
# Inverse of Matrix A:
# [0.3333333333333335, 1.0, -1.6666666666666665]
# [-0.33333333333333337, 0.0, 0.6666666666666666]
# [1.0, -2.0, 1.0]
#
# Logger Details:
# Step       Action                         Data
# ------------------------------------------------------------------------------------------
# 0          Init                           Augmented matrix: [[4, 7, 2, 1, 0, 0], [3, 6, 1, 0, 1, 0], [2, 5, 1, 0, 0, 1]]
# 1          Normalize                      Row 0 normalized, new row: [1.0, 1.75, 0.5, 0.25, 0.0, 0.0]
# 2          Eliminate                      Eliminated entry at row 1, column 0, new row: [0.0, 0.75, -0.5, -0.75, 1.0, 0.0]
# 3          Eliminate                      Eliminated entry at row 2, column 0, new row: [0.0, 1.5, 0.0, -0.5, 0.0, 1.0]
# 4          Normalize                      Row 1 normalized, new row: [0.0, 1.0, -0.6666666666666666, -1.0, 1.3333333333333333, 0.0]
# 5          Eliminate                      Eliminated entry at row 0, column 1, new row: [1.0, 0.0, 1.6666666666666665, 2.0, -2.333333333333333, 0.0]
# 6          Eliminate                      Eliminated entry at row 2, column 1, new row: [0.0, 0.0, 1.0, 1.0, -2.0, 1.0]
# 7          Normalize                      Row 2 normalized, new row: [0.0, 0.0, 1.0, 1.0, -2.0, 1.0]
# 8          Eliminate                      Eliminated entry at row 0, column 2, new row: [1.0, 0.0, 0.0, 0.3333333333333335, 1.0, -1.6666666666666665]
# 9          Eliminate                      Eliminated entry at row 1, column 2, new row: [0.0, 1.0, 0.0, -0.33333333333333337, 0.0, 0.6666666666666666]
# 10         Result                         Inverse matrix: [[0.3333333333333335, 1.0, -1.6666666666666665], [-0.33333333333333337, 0.0, 0.6666666666666666], [1.0, -2.0, 1.0]]

# %%
def identity(n):
    return [[1 if i == j else 0 for j in range(n)] for i in range(n)]

def transpose(A):
    m, n = len(A), len(A[0])
    return [[A[i][j] for i in range(m)] for j in range(n)]

def mat_mult(A, B):
    m, p, n = len(A), len(B), len(B[0])
    result = [[0 for _ in range(n)] for _ in range(m)]
    for i in range(m):
        for j in range(n):
            for k in range(p):
                result[i][j] += A[i][k] * B[k][j]
    return result

# %% [markdown]
# ## Eigenvalues Computation

# %%
def qr_decomposition(A, logger=None):
    m, n = len(A), len(A[0])
    Q = [[0.0 for _ in range(n)] for _ in range(m)]
    R = [[0.0 for _ in range(n)] for _ in range(n)]
    for j in range(n):
        v = [A[i][j] for i in range(m)]
        for k in range(j):
            R[k][j] = sum(Q[i][k] * A[i][j] for i in range(m))
            v = [v[i] - R[k][j] * Q[i][k] for i in range(m)]
        norm_v = math.sqrt(sum(x * x for x in v))
        R[j][j] = norm_v
        if norm_v < 1e-12:  # Handle near-zero column.
            continue
        for i in range(m):
            Q[i][j] = v[i] / norm_v
        if logger:
            logger.log("QR Decomp", f"Column {j} processed; norm = {norm_v}")
    return Q, R

# %%
def qr_algorithm_eig(A, tol=1e-10, max_iter=1000, logger=None):
    n = len(A)
    Ak = [row[:] for row in A]  # Copy of A
    Q_acc = identity(n)
    for it in range(max_iter):
        Q, R = qr_decomposition(Ak, logger)
        Ak_new = mat_mult(R, Q)
        Q_acc = mat_mult(Q_acc, Q)
        off_diag = 0.0
        for i in range(n):
            for j in range(n):
                if i != j:
                    off_diag += abs(Ak_new[i][j])
        if logger:
            logger.log("QR Iteration", f"Iteration {it}: off-diag sum = {off_diag}")
        if off_diag < tol:
            break
        Ak = Ak_new
    eigenvalues = [Ak[i][i] for i in range(n)]
    return eigenvalues, Q_acc

# %%
def svd(A, tol=1e-10, max_iter=1000, logger=None):
    m, n = len(A), len(A[0])
    At = transpose(A)
    AtA = mat_mult(At, A)
    eigenvalues, V = qr_algorithm_eig(AtA, tol, max_iter, logger)
    sigma = [math.sqrt(e) if e > 0 else 0.0 for e in eigenvalues]
    U = [[0.0 for _ in range(n)] for _ in range(m)]
    for i in range(n):
        if sigma[i] > tol:
            v_i = [V[j][i] for j in range(n)]
            Av = [sum(A[row][k] * v_i[k] for k in range(n)) for row in range(m)]
            for row in range(m):
                U[row][i] = Av[row] / sigma[i]
            if logger:
                logger.log("SVD", f"Computed U column {i} from singular value {sigma[i]}")
        else:
            for row in range(m):
                U[row][i] = 0.0
            if logger:
                logger.log("SVD", f"Singular value {i} is near zero; U column set to zero")
    return U, sigma, V

# %%
logger_qr = MatrixLogger()
A_qr = [
    [2, 1, 0],
    [1, 2, 1],
    [0, 1, 2]
]
eigs, evecs = qr_algorithm_eig(A_qr, tol=1e-8, max_iter=100, logger=logger_qr)
print("QR Algorithm Eigenvalue Decomposition")
print("Matrix A:")
for row in A_qr:
    print(row)
print("\nEigenvalues:")
print(eigs)
print("\nEigenvectors (columns of Q_acc):")
for row in evecs:
    print(row)
print("\nQR Logger Details:")
logger_qr.print_table()

logger_svd = MatrixLogger()
A_svd = [
    [1, 0],
    [0, 1],
    [1, 1]
]
U, sigma, V = svd(A_svd, tol=1e-8, max_iter=100, logger=logger_svd)
print("\nSVD of Matrix A")
print("Matrix A:")
for row in A_svd:
    print(row)
print("\nLeft Singular Vectors U (m x n):")
for row in U:
    print(row)
print("\nSingular Values (σ):")
print(sigma)
print("\nRight Singular Vectors V (n x n):")
for row in V:
    print(row)
print("\nSVD Logger Details:")
logger_svd.print_table()
# Out:
# QR Algorithm Eigenvalue Decomposition
# Matrix A:
# [2, 1, 0]
# [1, 2, 1]
# [0, 1, 2]
#
# Eigenvalues:
# [3.414213562373095, 2.0000000000000004, 0.5857864376269051]
#
# Eigenvectors (columns of Q_acc):
# [0.5000000014931172, -0.7071067801307547, 0.5]
# [0.7071067811865476, 1.4931171502845353e-09, -0.7071067811865475]
# [0.49999999850688276, 0.7071067822423416, 0.5]
#
# QR Logger Details:
# Step       Action                         Data
# ------------------------------------------------------------------------------------------
# 0          QR Decomp                      Column 0 processed; norm = 2.23606797749979
# 1          QR Decomp                      Column 1 processed; norm = 1.6733200530681511
# 2          QR Decomp                      Column 2 processed; norm = 1.0690449676496976
# 3          QR Iteration                   Iteration 0: off-diag sum = 2.7744160847094568
# 4          QR Decomp                      Column 0 processed; norm = 2.8982753492378874
# 5          QR Decomp                      Column 1 processed; norm = 2.166535841157586
# 6          QR Decomp                      Column 2 processed; norm = 0.637022057270606
# 7          QR Iteration                   Iteration 1: off-diag sum = 1.494489410519822
# 8          QR Decomp                      Column 0 processed; norm = 3.192252526113213
# 9          QR Decomp                      Column 1 processed; norm = 2.123952522864474
# 10         QR Decomp                      Column 2 processed; norm = 0.5899537246477261
# 11         QR Iteration                   Iteration 2: off-diag sum = 0.8487392374749381
# 12         QR Decomp                      Column 0 processed; norm = 3.3292810259172643
# 13         QR Decomp                      Column 1 processed; norm = 2.0498135710853274
# 14         QR Decomp                      Column 2 processed; norm = 0.5861316479046352
# 15         QR Iteration                   Iteration 3: off-diag sum = 0.4881518758750609
# 16         QR Decomp                      Column 0 processed; norm = 3.3838222398784668
# 17         QR Decomp                      Column 1 processed; norm = 2.017862075144911
# 18         QR Decomp                      Column 2 processed; norm = 0.5858156543299631
# 19         QR Iteration                   Iteration 4: off-diag sum = 0.28196660479785496
# 20         QR Decomp                      Column 0 processed; norm = 3.4036279699578267
# 21         QR Decomp                      Column 1 processed; norm = 2.00621163879723
# 22         QR Decomp                      Column 2 processed; norm = 0.5857889320738805
# 23         QR Iteration                   Iteration 5: off-diag sum = 0.1636237874123575
# 24         QR Decomp                      Column 0 processed; norm = 3.4105622571268386
# 25         QR Decomp                      Column 1 processed; norm = 2.002140444776232
# 26         QR Decomp                      Column 2 processed; norm = 0.5857866512631131
# 27         QR Iteration                   Iteration 6: off-diag sum = 0.09530907930382454
# 28         QR Decomp                      Column 0 processed; norm = 3.4129583893366062
# 29         QR Decomp                      Column 1 processed; norm = 2.00073547118713
# 30         QR Decomp                      Column 2 processed; norm = 0.585786455943575
# 31         QR Iteration                   Iteration 7: off-diag sum = 0.05565467941096044
# 32         QR Decomp                      Column 0 processed; norm = 3.413782590259937
# 33         QR Decomp                      Column 1 processed; norm = 2.0002524841258733
# 34         QR Decomp                      Column 2 processed; norm = 0.58578643919792
# 35         QR Iteration                   Iteration 8: off-diag sum = 0.032546484381272674
# 36         QR Decomp                      Column 0 processed; norm = 3.4140656449140097
# 37         QR Decomp                      Column 1 processed; norm = 2.000086651335396
# 38         QR Decomp                      Column 2 processed; norm = 0.5857864377616676
# 39         QR Iteration                   Iteration 9: off-diag sum = 0.01904835136630536
# 40         QR Decomp                      Column 0 processed; norm = 3.414162801449545
# 41         QR Decomp                      Column 1 processed; norm = 2.0000297354631997
# 42         QR Decomp                      Column 2 processed; norm = 0.5857864376384655
# 43         QR Iteration                   Iteration 10: off-diag sum = 0.011153153857976685
# 44         QR Decomp                      Column 0 processed; norm = 3.414196143544993
# 45         QR Decomp                      Column 1 processed; norm = 2.000010203761934
# 46         QR Decomp                      Column 2 processed; norm = 0.5857864376278966
# 47         QR Iteration                   Iteration 11: off-diag sum = 0.006531838572396882
# 48         QR Decomp                      Column 0 processed; norm = 3.414207585125278
# 49         QR Decomp                      Column 1 processed; norm = 2.000003501396545
# 50         QR Decomp                      Column 2 processed; norm = 0.58578643762699
# 51         QR Iteration                   Iteration 12: off-diag sum = 0.003825808878883487
# 52         QR Decomp                      Column 0 processed; norm = 3.4142115112999045
# 53         QR Decomp                      Column 1 processed; norm = 2.0000012014915547
# 54         QR Decomp                      Column 2 processed; norm = 0.5857864376269123
# 55         QR Iteration                   Iteration 13: off-diag sum = 0.0022409728764710203
# 56         QR Decomp                      Column 0 processed; norm = 3.414212858555339
# 57         QR Decomp                      Column 1 processed; norm = 2.0000004122869792
# 58         QR Decomp                      Column 2 processed; norm = 0.5857864376269056
# 59         QR Iteration                   Iteration 14: off-diag sum = 0.0013126920003281972
# 60         QR Decomp                      Column 0 processed; norm = 3.4142133208609398
# 61         QR Decomp                      Column 1 processed; norm = 2.000000141474555
# 62         QR Decomp                      Column 2 processed; norm = 0.5857864376269052
# 63         QR Iteration                   Iteration 15: off-diag sum = 0.0007689455463565383
# 64         QR Decomp                      Column 0 processed; norm = 3.414213479499215
# 65         QR Decomp                      Column 1 processed; norm = 2.0000000485463967
# 66         QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 67         QR Iteration                   Iteration 16: off-diag sum = 0.00045043445768001746
# 68         QR Decomp                      Column 0 processed; norm = 3.414213533935274
# 69         QR Decomp                      Column 1 processed; norm = 2.0000000166584906
# 70         QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 71         QR Iteration                   Iteration 17: off-diag sum = 0.00026385739421217456
# 72         QR Decomp                      Column 0 processed; norm = 3.414213552614777
# 73         QR Decomp                      Column 1 processed; norm = 2.000000005716291
# 74         QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 75         QR Iteration                   Iteration 18: off-diag sum = 0.0001545637890743368
# 76         QR Decomp                      Column 0 processed; norm = 3.414213559024569
# 77         QR Decomp                      Column 1 processed; norm = 2.0000000019615216
# 78         QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 79         QR Iteration                   Iteration 19: off-diag sum = 9.054128521896607e-05
# 80         QR Decomp                      Column 0 processed; norm = 3.414213561224062
# 81         QR Decomp                      Column 1 processed; norm = 2.0000000006730887
# 82         QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 83         QR Iteration                   Iteration 20: off-diag sum = 5.303783167209364e-05
# 84         QR Decomp                      Column 0 processed; norm = 3.4142135619788085
# 85         QR Decomp                      Column 1 processed; norm = 2.000000000230968
# 86         QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 87         QR Iteration                   Iteration 21: off-diag sum = 3.106883507465305e-05
# 88         QR Decomp                      Column 0 processed; norm = 3.414213562237797
# 89         QR Decomp                      Column 1 processed; norm = 2.000000000079256
# 90         QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 91         QR Iteration                   Iteration 22: off-diag sum = 1.819970005167997e-05
# 92         QR Decomp                      Column 0 processed; norm = 3.4142135623266676
# 93         QR Decomp                      Column 1 processed; norm = 2.000000000027197
# 94         QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 95         QR Iteration                   Iteration 23: off-diag sum = 1.0661136824200258e-05
# 96         QR Decomp                      Column 0 processed; norm = 3.4142135623571632
# 97         QR Decomp                      Column 1 processed; norm = 2.000000000009333
# 98         QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 99         QR Iteration                   Iteration 24: off-diag sum = 6.245149175451367e-06
# 100        QR Decomp                      Column 0 processed; norm = 3.4142135623676277
# 101        QR Decomp                      Column 1 processed; norm = 2.0000000000032028
# 102        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 103        QR Iteration                   Iteration 25: off-diag sum = 3.658323633646447e-06
# 104        QR Decomp                      Column 0 processed; norm = 3.4142135623712186
# 105        QR Decomp                      Column 1 processed; norm = 2.0000000000010996
# 106        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 107        QR Iteration                   Iteration 26: off-diag sum = 2.1429963532875963e-06
# 108        QR Decomp                      Column 0 processed; norm = 3.414213562372451
# 109        QR Decomp                      Column 1 processed; norm = 2.000000000000378
# 110        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 111        QR Iteration                   Iteration 27: off-diag sum = 1.2553381951755044e-06
# 112        QR Decomp                      Column 0 processed; norm = 3.4142135623728738
# 113        QR Decomp                      Column 1 processed; norm = 2.00000000000013
# 114        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 115        QR Iteration                   Iteration 28: off-diag sum = 7.353600882109681e-07
# 116        QR Decomp                      Column 0 processed; norm = 3.4142135623730185
# 117        QR Decomp                      Column 1 processed; norm = 2.0000000000000453
# 118        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 119        QR Iteration                   Iteration 29: off-diag sum = 4.307639662566891e-07
# 120        QR Decomp                      Column 0 processed; norm = 3.4142135623730683
# 121        QR Decomp                      Column 1 processed; norm = 2.000000000000016
# 122        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 123        QR Iteration                   Iteration 30: off-diag sum = 2.5233568934578365e-07
# 124        QR Decomp                      Column 0 processed; norm = 3.4142135623730856
# 125        QR Decomp                      Column 1 processed; norm = 2.0000000000000058
# 126        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 127        QR Iteration                   Iteration 31: off-diag sum = 1.4781482472532135e-07
# 128        QR Decomp                      Column 0 processed; norm = 3.414213562373092
# 129        QR Decomp                      Column 1 processed; norm = 2.000000000000002
# 130        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 131        QR Iteration                   Iteration 32: off-diag sum = 8.658791980595176e-08
# 132        QR Decomp                      Column 0 processed; norm = 3.414213562373094
# 133        QR Decomp                      Column 1 processed; norm = 2.000000000000001
# 134        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 135        QR Iteration                   Iteration 33: off-diag sum = 5.072202929344065e-08
# 136        QR Decomp                      Column 0 processed; norm = 3.4142135623730945
# 137        QR Decomp                      Column 1 processed; norm = 2.0000000000000004
# 138        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 139        QR Iteration                   Iteration 34: off-diag sum = 2.971227705988778e-08
# 140        QR Decomp                      Column 0 processed; norm = 3.414213562373095
# 141        QR Decomp                      Column 1 processed; norm = 2.0000000000000004
# 142        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 143        QR Iteration                   Iteration 35: off-diag sum = 1.7405049144182397e-08
# 144        QR Decomp                      Column 0 processed; norm = 3.414213562373095
# 145        QR Decomp                      Column 1 processed; norm = 2.0000000000000004
# 146        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 147        QR Iteration                   Iteration 36: off-diag sum = 1.0195641946558039e-08
# 148        QR Decomp                      Column 0 processed; norm = 3.414213562373095
# 149        QR Decomp                      Column 1 processed; norm = 2.0000000000000004
# 150        QR Decomp                      Column 2 processed; norm = 0.5857864376269051
# 151        QR Iteration                   Iteration 37: off-diag sum = 5.972468986912351e-09
#
# SVD of Matrix A
# Matrix A:
# [1, 0]
# [0, 1]
# [1, 1]
#
# Left Singular Vectors U (m x n):
# [0.4082482908151166, -0.707106780578159]
# [0.4082482901126099, 0.7071067817949368]
# [0.8164965809277265, 1.2167777896365808e-09]
#
# Singular Values (σ):
# [1.732050807568877, 0.9999999999999999]
#
# Right Singular Vectors V (n x n):
# [0.7071067817949365, -0.7071067805781589]
# [0.7071067805781591, 0.7071067817949367]
#
# SVD Logger Details:
# Step       Action                         Data
# ------------------------------------------------------------------------------------------
# 0          QR Decomp                      Column 0 processed; norm = 2.23606797749979
# 1          QR Decomp                      Column 1 processed; norm = 1.3416407864998738
# 2          QR Iteration                   Iteration 0: off-diag sum = 1.2000000000000002
# 3          QR Decomp                      Column 0 processed; norm = 2.8635642126552705
# 4          QR Decomp                      Column 1 processed; norm = 1.0476454436543674
# 5          QR Iteration                   Iteration 1: off-diag sum = 0.4390243902439029
# 6          QR Decomp                      Column 0 processed; norm = 2.9836955314492535
# 7          QR Decomp                      Column 1 processed; norm = 1.0054645215568716
# 8          QR Iteration                   Iteration 2: off-diag sum = 0.14794520547945236
# 9          QR Decomp                      Column 0 processed; norm = 2.9981729596356526
# 10         QR Decomp                      Column 1 processed; norm = 1.0006093845781896
# 11         QR Iteration                   Iteration 3: off-diag sum = 0.04937519049070431
# 12         QR Decomp                      Column 0 processed; norm = 2.9997968030341746
# 13         QR Decomp                      Column 1 processed; norm = 1.0000677369099198
# 14         QR Iteration                   Iteration 4: off-diag sum = 0.01646062658763782
# 15         QR Decomp                      Column 0 processed; norm = 2.999977420180337
# 16         QR Decomp                      Column 1 processed; norm = 1.0000075266632045
# 17         QR Iteration                   Iteration 5: off-diag sum = 0.005486958125251893
# 18         QR Decomp                      Column 0 processed; norm = 2.999997491101774
# 19         QR Decomp                      Column 1 processed; norm = 1.0000008363001078
# 20         QR Iteration                   Iteration 6: off-diag sum = 0.0018289891009145038
# 21         QR Decomp                      Column 0 processed; norm = 2.9999997212331673
# 22         QR Decomp                      Column 1 processed; norm = 1.0000000929222859
# 23         QR Iteration                   Iteration 7: off-diag sum = 0.0006096631469408834
# 24         QR Decomp                      Column 0 processed; norm = 2.999999969025903
# 25         QR Decomp                      Column 1 processed; norm = 1.0000000103246989
# 26         QR Iteration                   Iteration 8: off-diag sum = 0.0002032210531768316
# 27         QR Decomp                      Column 0 processed; norm = 2.9999999965584334
# 28         QR Decomp                      Column 1 processed; norm = 1.0000000011471886
# 29         QR Iteration                   Iteration 9: off-diag sum = 6.774035121451063e-05
# 30         QR Decomp                      Column 0 processed; norm = 2.999999999617603
# 31         QR Decomp                      Column 1 processed; norm = 1.0000000001274651
# 32         QR Iteration                   Iteration 10: off-diag sum = 2.2580117077404728e-05
# 33         QR Decomp                      Column 0 processed; norm = 2.999999999957511
# 34         QR Decomp                      Column 1 processed; norm = 1.0000000000141627
# 35         QR Iteration                   Iteration 11: off-diag sum = 7.526705692826263e-06
# 36         QR Decomp                      Column 0 processed; norm = 2.999999999995278
# 37         QR Decomp                      Column 1 processed; norm = 1.0000000000015734
# 38         QR Iteration                   Iteration 12: off-diag sum = 2.508901897761472e-06
# 39         QR Decomp                      Column 0 processed; norm = 2.9999999999994746
# 40         QR Decomp                      Column 1 processed; norm = 1.0000000000001745
# 41         QR Iteration                   Iteration 13: off-diag sum = 8.363006327322709e-07
# 42         QR Decomp                      Column 0 processed; norm = 2.999999999999941
# 43         QR Decomp                      Column 1 processed; norm = 1.000000000000019
# 44         QR Iteration                   Iteration 14: off-diag sum = 2.787668777222557e-07
# 45         QR Decomp                      Column 0 processed; norm = 2.9999999999999925
# 46         QR Decomp                      Column 1 processed; norm = 1.000000000000002
# 47         QR Iteration                   Iteration 15: off-diag sum = 9.292229271890668e-08
# 48         QR Decomp                      Column 0 processed; norm = 2.9999999999999982
# 49         QR Decomp                      Column 1 processed; norm = 1.0
# 50         QR Iteration                   Iteration 16: off-diag sum = 3.0974097717790004e-08
# 51         QR Decomp                      Column 0 processed; norm = 2.9999999999999987
# 52         QR Decomp                      Column 1 processed; norm = 0.9999999999999998
# 53         QR Iteration                   Iteration 17: off-diag sum = 1.0324699384084413e-08
# 54         QR Decomp                      Column 0 processed; norm = 2.9999999999999987
# 55         QR Decomp                      Column 1 processed; norm = 0.9999999999999998
# 56         QR Iteration                   Iteration 18: off-diag sum = 3.441566606182549e-09
# 57         SVD                            Computed U column 0 from singular value 1.732050807568877
# 58         SVD                            Computed U column 1 from singular value 0.9999999999999999

# %% [markdown]
# # Fourier Transforms

# %%
class FourierLogger:
    def __init__(self):
        self.logs = []
        self.step = 0
    def log(self, action, data):
        self.logs.append({'step': self.step, 'action': action, 'data': data})
        self.step += 1
    def clear(self):
        self.logs = []
        self.step = 0
    def print_table(self):
        print("{:<10} {:<30} {:<50}".format("Step", "Action", "Data"))
        print("-" * 90)
        for entry in self.logs:
            print("{:<10} {:<30} {:<50}".format(entry['step'], entry['action'], str(entry['data'])))
    def get_logs(self):
        return self.logs

# %% [markdown]
# ## Discrete Fourier Transforms

# %%
def principal_nth_root_of_unity(n):
    return cmath.exp(2j * cmath.pi / n)

def dft(a, omega, logger=None):
    n = len(a)
    b = [0] * n
    for i in range(n):
        s = 0
        for j in range(n):
            s += a[j] * (omega ** (i * j))
        b[i] = s
        if logger:
            logger.log("DFT", f"b[{i}] = {s}")
    return b

def inverse_dft(b, omega, logger=None):
    n = len(b)
    a = [0] * n
    inv_n = 1 / n
    for j in range(n):
        s = 0
        for i in range(n):
            s += b[i] * (omega ** (-i * j))
        a[j] = inv_n * s
        if logger:
            logger.log("Inverse DFT", f"a[{j}] = {a[j]}")
    return a

def convolution(a, b, omega, logger=None):
    n = len(a)
    A = dft(a, omega, logger)
    B = dft(b, omega, logger)
    C = [A[i] * B[i] for i in range(n)]
    c = inverse_dft(C, omega, logger)
    return c

# %%
a = [1, 2, 3, 4]
n = len(a)
omega = principal_nth_root_of_unity(n)
logger = FourierLogger()

b = dft(a, omega, logger)
print("DFT Result:")
for val in b:
    print(val)
print("\nDFT Logger:")
logger.print_table()

logger.clear()
a_reconstructed = inverse_dft(b, omega, logger)
print("\nInverse DFT Result:")
for val in a_reconstructed:
    print(val)
print("\nInverse DFT Logger:")
logger.print_table()

# Example usage of convolution
u = [1, 2, 3, 4]
v = [4, 3, 2, 1]
logger.clear()
conv = convolution(u, v, omega, logger)
print("\nConvolution (via DFT) Result:")
for val in conv:
    print(val)
print("\nConvolution Logger:")
logger.print_table()
# Out:
# DFT Result:
# (10+0j)
# (-2.0000000000000004-1.9999999999999996j)
# (-2+9.797174393178826e-16j)
# (-1.9999999999999982+2.000000000000001j)
#
# DFT Logger:
# Step       Action                         Data
# ------------------------------------------------------------------------------------------
# 0          DFT                            b[0] = (10+0j)
# 1          DFT                            b[1] = (-2.0000000000000004-1.9999999999999996j)
# 2          DFT                            b[2] = (-2+9.797174393178826e-16j)
# 3          DFT                            b[3] = (-1.9999999999999982+2.000000000000001j)
#
# Inverse DFT Result:
# (1.0000000000000004+5.551115123125783e-16j)
# (2+2.7755575615628914e-16j)
# (2.9999999999999996+1.1102230246251565e-16j)
# (4-2.7755575615628914e-16j)
#
# Inverse DFT Logger:
# Step       Action                         Data
# ------------------------------------------------------------------------------------------
# 0          Inverse DFT                    a[0] = (1.0000000000000004+5.551115123125783e-16j)
# 1          Inverse DFT                    a[1] = (2+2.7755575615628914e-16j)
# 2          Inverse DFT                    a[2] = (2.9999999999999996+1.1102230246251565e-16j)
# 3          Inverse DFT                    a[3] = (4-2.7755575615628914e-16j)
#
# Convolution (via DFT) Result:
# (24-4.440892098500626e-16j)
# (22+1.5339034021171336e-16j)
# (24+8.881784197001252e-16j)
# (30+5.813977392766981e-16j)
#
# Convolution Logger:
# Step       Action                         Data
# ------------------------------------------------------------------------------------------
# 0          DFT                            b[0] = (10+0j)
# 1          DFT                            b[1] = (-2.0000000000000004-1.9999999999999996j)
# 2          DFT                            b[2] = (-2+9.797174393178826e-16j)
# 3          DFT                            b[3] = (-1.9999999999999982+2.000000000000001j)
# 4          DFT                            b[0] = (10+0j)
# 5          DFT                            b[1] = (1.9999999999999998+2.0000000000000004j)
# 6          DFT                            b[2] = (2+2.449293598294706e-16j)
# 7          DFT                            b[3] = (2-1.9999999999999991j)
# 8          Inverse DFT                    a[0] = (24-4.440892098500626e-16j)
# 9          Inverse DFT                    a[1] = (22+1.5339034021171336e-16j)
# 10         Inverse DFT                    a[2] = (24+8.881784197001252e-16j)
# 11         Inverse DFT                    a[3] = (30+5.813977392766981e-16j)

# %% [markdown]
# ## Fast Fourier Transforms

# %%
def fft(a, logger=None, depth=0):
    n = len(a)
    if n == 1:
        if logger:
            logger.log(f"Base case (depth {depth})", f"Return {a}")
        return a
    even = fft(a[0::2], logger, depth + 1)
    odd = fft(a[1::2], logger, depth + 1)
    y = [0] * n
    omega_n = cmath.exp(2j * cmath.pi / n)
    for k in range(n // 2):
        t = (omega_n ** k) * odd[k]
        y[k] = even[k] + t
        y[k + n // 2] = even[k] - t
        if logger:
            logger.log(f"Depth {depth}, k = {k}",
                       f"even[{k}] = {even[k]}, odd[{k}] = {odd[k]}, "
                       f"t = {t}, y[{k}] = {y[k]}, y[{k + n//2}] = {y[k + n//2]}")
    if logger:
         logger.log(f"Depth {depth} Combined", f"y = {y}")
    return y

def ifft(a, logger=None):
    n = len(a)
    a_conj = [x.conjugate() for x in a]
    if logger:
        logger.log("IFFT", f"Conjugated input: {a_conj}")
    y = fft(a_conj, logger, depth=0)
    y = [x.conjugate() / n for x in y]
    if logger:
        logger.log("IFFT", f"Final result after conjugation and division: {y}")
    return y

# %%
logger_fft = FourierLogger()
a = [1, 2, 3, 4, 5, 6, 7, 8]  # Input vector (length must be a power of 2)
result_fft = fft(a, logger_fft)
print("FFT Result:")
for val in result_fft:
    print(val)
print("\nFFT Logger Details:")
logger_fft.print_table()

logger_fft.clear()
result_ifft = ifft(result_fft, logger_fft)
print("\nInverse FFT Result (should approximate the original vector):")
for val in result_ifft:
    print(val)
print("\nInverse FFT Logger Details:")
logger_fft.print_table()
# Out:
# FFT Result:
# (36+0j)
# (-4-9.65685424949238j)
# (-4.000000000000001-4j)
# (-4.000000000000002-1.6568542494923797j)
# (-4+0j)
# (-3.9999999999999996+1.6568542494923797j)
# (-3.999999999999999+4j)
# (-3.999999999999998+9.65685424949238j)
#
# FFT Logger Details:
# Step       Action                         Data
# ------------------------------------------------------------------------------------------
# 0          Base case (depth 3)            Return [1]
# 1          Base case (depth 3)            Return [5]
# 2          Depth 2, k = 0                 even[0] = 1, odd[0] = 5, t = (5+0j), y[0] = (6+0j), y[1] = (-4+0j)
# 3          Depth 2 Combined               y = [(6+0j), (-4+0j)]
# 4          Base case (depth 3)            Return [3]
# 5          Base case (depth 3)            Return [7]
# 6          Depth 2, k = 0                 even[0] = 3, odd[0] = 7, t = (7+0j), y[0] = (10+0j), y[1] = (-4+0j)
# 7          Depth 2 Combined               y = [(10+0j), (-4+0j)]
# 8          Depth 1, k = 0                 even[0] = (6+0j), odd[0] = (10+0j), t = (10+0j), y[0] = (16+0j), y[2] = (-4+0j)
# 9          Depth 1, k = 1                 even[1] = (-4+0j), odd[1] = (-4+0j), t = (-2.4492935982947064e-16-4j), y[1] = (-4-4j), y[3] = (-3.9999999999999996+4j)
# 10         Depth 1 Combined               y = [(16+0j), (-4-4j), (-4+0j), (-3.9999999999999996+4j)]
# 11         Base case (depth 3)            Return [2]
# 12         Base case (depth 3)            Return [6]
# 13         Depth 2, k = 0                 even[0] = 2, odd[0] = 6, t = (6+0j), y[0] = (8+0j), y[1] = (-4+0j)
# 14         Depth 2 Combined               y = [(8+0j), (-4+0j)]
# 15         Base case (depth 3)            Return [4]
# 16         Base case (depth 3)            Return [8]
# 17         Depth 2, k = 0                 even[0] = 4, odd[0] = 8, t = (8+0j), y[0] = (12+0j), y[1] = (-4+0j)
# 18         Depth 2 Combined               y = [(12+0j), (-4+0j)]
# 19         Depth 1, k = 0                 even[0] = (8+0j), odd[0] = (12+0j), t = (12+0j), y[0] = (20+0j), y[2] = (-4+0j)
# 20         Depth 1, k = 1                 even[1] = (-4+0j), odd[1] = (-4+0j), t = (-2.4492935982947064e-16-4j), y[1] = (-4-4j), y[3] = (-3.9999999999999996+4j)
# 21         Depth 1 Combined               y = [(20+0j), (-4-4j), (-4+0j), (-3.9999999999999996+4j)]
# 22         Depth 0, k = 0                 even[0] = (16+0j), odd[0] = (20+0j), t = (20+0j), y[0] = (36+0j), y[4] = (-4+0j)
# 23         Depth 0, k = 1                 even[1] = (-4-4j), odd[1] = (-4-4j), t = (-4.440892098500626e-16-5.65685424949238j), y[1] = (-4-9.65685424949238j), y[5] = (-3.9999999999999996+1.6568542494923797j)
# 24         Depth 0, k = 2                 even[2] = (-4+0j), odd[2] = (-4+0j), t = (-8.881784197001252e-16-4j), y[2] = (-4.000000000000001-4j), y[6] = (-3.999999999999999+4j)
# 25         Depth 0, k = 3                 even[3] = (-3.9999999999999996+4j), odd[3] = (-3.9999999999999996+4j), t = (-1.7763568394002505e-15-5.65685424949238j), y[3] = (-4.000000000000002-1.6568542494923797j), y[7] = (-3.999999999999998+9.65685424949238j)
# 26         Depth 0 Combined               y = [(36+0j), (-4-9.65685424949238j), (-4.000000000000001-4j), (-4.000000000000002-1.6568542494923797j), (-4+0j), (-3.9999999999999996+1.6568542494923797j), (-3.999999999999999+4j), (-3.999999999999998+9.65685424949238j)]
#
# Inverse FFT Result (should approximate the original vector):
# (1-0j)
# (2.0000000000000004+2.718345674301793e-16j)
# (3-4.440892098500626e-16j)
# (4-3.8285686989269494e-16j)
# (5-0j)
# (6+4.978996250514798e-17j)
# (7+4.440892098500626e-16j)
# (8+6.123233995736767e-17j)
#
# Inverse FFT Logger Details:
# Step       Action                         Data
# ------------------------------------------------------------------------------------------
# 0          IFFT                           Conjugated input: [(36-0j), (-4+9.65685424949238j), (-4.000000000000001+4j), (-4.000000000000002+1.6568542494923797j), (-4-0j), (-3.9999999999999996-1.6568542494923797j), (-3.999999999999999-4j), (-3.999999999999998-9.65685424949238j)]
# 1          Base case (depth 3)            Return [(36-0j)]
# 2          Base case (depth 3)            Return [(-4-0j)]
# 3          Depth 2, k = 0                 even[0] = (36-0j), odd[0] = (-4-0j), t = (-4-0j), y[0] = (32-0j), y[1] = (40+0j)
# 4          Depth 2 Combined               y = [(32-0j), (40+0j)]
# 5          Base case (depth 3)            Return [(-4.000000000000001+4j)]
# 6          Base case (depth 3)            Return [(-3.999999999999999-4j)]
# 7          Depth 2, k = 0                 even[0] = (-4.000000000000001+4j), odd[0] = (-3.999999999999999-4j), t = (-3.999999999999999-4j), y[0] = (-8+0j), y[1] = (-1.7763568394002505e-15+8j)
# 8          Depth 2 Combined               y = [(-8+0j), (-1.7763568394002505e-15+8j)]
# 9          Depth 1, k = 0                 even[0] = (32-0j), odd[0] = (-8+0j), t = (-8+0j), y[0] = (24+0j), y[2] = (40-0j)
# 10         Depth 1, k = 1                 even[1] = (40+0j), odd[1] = (-1.7763568394002505e-15+8j), t = (-8-1.286498119741309e-15j), y[1] = (32-1.286498119741309e-15j), y[3] = (48+1.286498119741309e-15j)
# 11         Depth 1 Combined               y = [(24+0j), (32-1.286498119741309e-15j), (40-0j), (48+1.286498119741309e-15j)]
# 12         Base case (depth 3)            Return [(-4+9.65685424949238j)]
# 13         Base case (depth 3)            Return [(-3.9999999999999996-1.6568542494923797j)]
# 14         Depth 2, k = 0                 even[0] = (-4+9.65685424949238j), odd[0] = (-3.9999999999999996-1.6568542494923797j), t = (-3.9999999999999996-1.6568542494923797j), y[0] = (-8+8j), y[1] = (-4.440892098500626e-16+11.31370849898476j)
# 15         Depth 2 Combined               y = [(-8+8j), (-4.440892098500626e-16+11.31370849898476j)]
# 16         Base case (depth 3)            Return [(-4.000000000000002+1.6568542494923797j)]
# 17         Base case (depth 3)            Return [(-3.999999999999998-9.65685424949238j)]
# 18         Depth 2, k = 0                 even[0] = (-4.000000000000002+1.6568542494923797j), odd[0] = (-3.999999999999998-9.65685424949238j), t = (-3.999999999999998-9.65685424949238j), y[0] = (-8-8j), y[1] = (-3.9968028886505635e-15+11.31370849898476j)
# 19         Depth 2 Combined               y = [(-8-8j), (-3.9968028886505635e-15+11.31370849898476j)]
# 20         Depth 1, k = 0                 even[0] = (-8+8j), odd[0] = (-8-8j), t = (-8-8j), y[0] = (-16+0j), y[2] = 16j
# 21         Depth 1, k = 1                 even[1] = (-4.440892098500626e-16+11.31370849898476j), odd[1] = (-3.9968028886505635e-15+11.31370849898476j), t = (-11.31370849898476-3.304038043662169e-15j), y[1] = (-11.31370849898476+11.313708498984756j), y[3] = (11.31370849898476+11.313708498984763j)
# 22         Depth 1 Combined               y = [(-16+0j), (-11.31370849898476+11.313708498984756j), 16j, (11.31370849898476+11.313708498984763j)]
# 23         Depth 0, k = 0                 even[0] = (24+0j), odd[0] = (-16+0j), t = (-16+0j), y[0] = (8+0j), y[4] = (40+0j)
# 24         Depth 0, k = 1                 even[1] = (32-1.286498119741309e-15j), odd[1] = (-11.31370849898476+11.313708498984756j), t = (-15.999999999999996-8.881784197001252e-16j), y[1] = (16.000000000000004-2.1746765394414343e-15j), y[5] = (48-3.9831970004118385e-16j)
# 25         Depth 0, k = 2                 even[2] = (40-0j), odd[2] = 16j, t = (-16+3.552713678800501e-15j), y[2] = (24+3.552713678800501e-15j), y[6] = (56-3.552713678800501e-15j)
# 26         Depth 0, k = 3                 even[3] = (48+1.286498119741309e-15j), odd[3] = (11.31370849898476+11.313708498984763j), t = (-16+1.7763568394002505e-15j), y[3] = (32+3.0628549591415595e-15j), y[7] = (64-4.898587196589414e-16j)
# 27         Depth 0 Combined               y = [(8+0j), (16.000000000000004-2.1746765394414343e-15j), (24+3.552713678800501e-15j), (32+3.0628549591415595e-15j), (40+0j), (48-3.9831970004118385e-16j), (56-3.552713678800501e-15j), (64-4.898587196589414e-16j)]
# 28         IFFT                           Final result after conjugation and division: [(1-0j), (2.0000000000000004+2.718345674301793e-16j), (3-4.440892098500626e-16j), (4-3.8285686989269494e-16j), (5-0j), (6+4.978996250514798e-17j), (7+4.440892098500626e-16j), (8+6.123233995736767e-17j)]

# %%
def modinv(a, mod):
    return pow(a, -1, mod)

def fft_mod(a, omega, mod, logger=None, depth=0):
    n = len(a)
    if n == 1:
        if logger:
            logger.log(f"FFT Base (depth {depth})", f"Input: {a}")
        return a[:]
    a_even = fft_mod(a[0::2], (omega*omega) % mod, mod, logger, depth+1)
    a_odd  = fft_mod(a[1::2], (omega*omega) % mod, mod, logger, depth+1)
    y = [0] * n
    omega_k = 1
    for k in range(n//2):
        t = (omega_k * a_odd[k]) % mod
        y[k] = (a_even[k] + t) % mod
        y[k + n//2] = (a_even[k] - t) % mod
        if logger:
            logger.log(f"FFT Depth {depth}", f"k={k}, omega_k={omega_k}, t={t}, y[{k}]={y[k]}, y[{k + n//2}]={y[k + n//2]}")
        omega_k = (omega_k * omega) % mod
    if logger:
        logger.log(f"FFT Combine (depth {depth})", f"y = {y}")
    return y

def ifft_mod(a, omega, mod, logger=None):
    n = len(a)
    # Compute inverse omega = omega_inv
    omega_inv = modinv(omega, mod)
    y = fft_mod(a, omega_inv, mod, logger)
    n_inv = modinv(n, mod)
    return [(val * n_inv) % mod for val in y]

def int_to_poly(x, block_size, b, logger=None):
    base = 1 << block_size
    coeff = []
    for _ in range(b):
        coeff.append(x % base)
        x //= base
    if logger:
        logger.log("int_to_poly", f"Digits: {coeff} (base {base})")
    return coeff

def poly_to_int(coeff, block_size, logger=None):
    base = 1 << block_size
    carry = 0
    for i in range(len(coeff)):
        total = coeff[i] + carry
        coeff[i] = total % base
        carry = total // base
    if logger:
        logger.log("poly_to_int", f"Normalized coeff: {coeff}, final carry: {carry}")
    result = 0
    for i in reversed(range(len(coeff))):
        result = result * base + coeff[i]
    result += carry * (base ** len(coeff))
    return result

def next_power_of_two(x):
    return 1 << (x - 1).bit_length()

def poly_mul_mod(p, q, n_fft, mod, logger=None):
    # Zero-pad to length n_fft
    P = p + [0]*(n_fft - len(p))
    Q = q + [0]*(n_fft - len(q))
    if logger:
        logger.log("poly_mul_mod", f"P padded: {P}")
        logger.log("poly_mul_mod", f"Q padded: {Q}")
    g = 3
    omega = pow(g, (mod-1)//n_fft, mod)
    if logger:
        logger.log("poly_mul_mod", f"Using omega = {omega} (n_fft={n_fft}, mod={mod})")
    FP = fft_mod(P, omega, mod, logger)
    FQ = fft_mod(Q, omega, mod, logger)
    Fprod = [(FP[i] * FQ[i]) % mod for i in range(n_fft)]
    if logger:
        logger.log("poly_mul_mod", f"Pointwise product: {Fprod}")
    prod = ifft_mod(Fprod, omega, mod, logger)
    if logger:
        logger.log("poly_mul_mod", f"Convolution result (raw): {prod}")
    return prod

def schoenhage_strassen(u, v, block_size=4, b=8, mod=65537, logger=None):
    poly_u = int_to_poly(u, block_size, b, logger)
    poly_v = int_to_poly(v, block_size, b, logger)

    n_fft = next_power_of_two(2 * b)
    if logger:
        logger.log("schoenhage_strassen", f"FFT length chosen: {n_fft}")

    prod_poly = poly_mul_mod(poly_u, poly_v, n_fft, mod, logger)
    conv_coeff = prod_poly[:2*b - 1]
    if logger:
        logger.log("schoenhage_strassen", f"Raw convolution coefficients: {conv_coeff}")
    result = poly_to_int(conv_coeff, block_size, logger)
    if logger:
        logger.log("schoenhage_strassen", f"Final integer result: {result}")
    return result

# %%
logger_ss = FourierLogger()

u = 123456789
v = 987654321

result_ss = schoenhage_strassen(u, v, block_size=4, b=8, mod=65537, logger=logger_ss)
print("Integer u:", u)
print("Integer v:", v)
print("Product u * v (Schönhage–Strassen):", result_ss)
print("\nSchönhage–Strassen Logger Details:")
logger_ss.print_table()
# Out:
# Integer u: 123456789
# Integer v: 987654321
# Product u * v (Schönhage–Strassen): 121932631112635269
#
# Schönhage–Strassen Logger Details:
# Step       Action                         Data
# ------------------------------------------------------------------------------------------
# 0          int_to_poly                    Digits: [5, 1, 13, 12, 11, 5, 7, 0] (base 16)
# 1          int_to_poly                    Digits: [1, 11, 8, 6, 14, 13, 10, 3] (base 16)
# 2          schoenhage_strassen            FFT length chosen: 16
# 3          poly_mul_mod                   P padded: [5, 1, 13, 12, 11, 5, 7, 0, 0, 0, 0, 0, 0, 0, 0, 0]
# 4          poly_mul_mod                   Q padded: [1, 11, 8, 6, 14, 13, 10, 3, 0, 0, 0, 0, 0, 0, 0, 0]
# 5          poly_mul_mod                   Using omega = 64 (n_fft=16, mod=65537)
# 6          FFT Base (depth 4)             Input: [5]
# 7          FFT Base (depth 4)             Input: [0]
# 8          FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=5, y[1]=5
# 9          FFT Combine (depth 3)          y = [5, 5]
# 10         FFT Base (depth 4)             Input: [11]
# 11         FFT Base (depth 4)             Input: [0]
# 12         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=11, y[1]=11
# 13         FFT Combine (depth 3)          y = [11, 11]
# 14         FFT Depth 2                    k=0, omega_k=1, t=11, y[0]=16, y[2]=65531
# 15         FFT Depth 2                    k=1, omega_k=65281, t=62721, y[1]=62726, y[3]=2821
# 16         FFT Combine (depth 2)          y = [16, 62726, 65531, 2821]
# 17         FFT Base (depth 4)             Input: [13]
# 18         FFT Base (depth 4)             Input: [0]
# 19         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=13, y[1]=13
# 20         FFT Combine (depth 3)          y = [13, 13]
# 21         FFT Base (depth 4)             Input: [7]
# 22         FFT Base (depth 4)             Input: [0]
# 23         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=7, y[1]=7
# 24         FFT Combine (depth 3)          y = [7, 7]
# 25         FFT Depth 2                    k=0, omega_k=1, t=7, y[0]=20, y[2]=6
# 26         FFT Depth 2                    k=1, omega_k=65281, t=63745, y[1]=63758, y[3]=1805
# 27         FFT Combine (depth 2)          y = [20, 63758, 6, 1805]
# 28         FFT Depth 1                    k=0, omega_k=1, t=20, y[0]=36, y[4]=65533
# 29         FFT Depth 1                    k=1, omega_k=4096, t=53360, y[1]=50549, y[5]=9366
# 30         FFT Depth 1                    k=2, omega_k=65281, t=64001, y[2]=63995, y[6]=1530
# 31         FFT Depth 1                    k=3, omega_k=16, t=28880, y[3]=31701, y[7]=39478
# 32         FFT Combine (depth 1)          y = [36, 50549, 63995, 31701, 65533, 9366, 1530, 39478]
# 33         FFT Base (depth 4)             Input: [1]
# 34         FFT Base (depth 4)             Input: [0]
# 35         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=1, y[1]=1
# 36         FFT Combine (depth 3)          y = [1, 1]
# 37         FFT Base (depth 4)             Input: [5]
# 38         FFT Base (depth 4)             Input: [0]
# 39         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=5, y[1]=5
# 40         FFT Combine (depth 3)          y = [5, 5]
# 41         FFT Depth 2                    k=0, omega_k=1, t=5, y[0]=6, y[2]=65533
# 42         FFT Depth 2                    k=1, omega_k=65281, t=64257, y[1]=64258, y[3]=1281
# 43         FFT Combine (depth 2)          y = [6, 64258, 65533, 1281]
# 44         FFT Base (depth 4)             Input: [12]
# 45         FFT Base (depth 4)             Input: [0]
# 46         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=12, y[1]=12
# 47         FFT Combine (depth 3)          y = [12, 12]
# 48         FFT Base (depth 4)             Input: [0]
# 49         FFT Base (depth 4)             Input: [0]
# 50         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=0, y[1]=0
# 51         FFT Combine (depth 3)          y = [0, 0]
# 52         FFT Depth 2                    k=0, omega_k=1, t=0, y[0]=12, y[2]=12
# 53         FFT Depth 2                    k=1, omega_k=65281, t=0, y[1]=12, y[3]=12
# 54         FFT Combine (depth 2)          y = [12, 12, 12, 12]
# 55         FFT Depth 1                    k=0, omega_k=1, t=12, y[0]=18, y[4]=65531
# 56         FFT Depth 1                    k=1, omega_k=4096, t=49152, y[1]=47873, y[5]=15106
# 57         FFT Depth 1                    k=2, omega_k=65281, t=62465, y[2]=62461, y[6]=3068
# 58         FFT Depth 1                    k=3, omega_k=16, t=192, y[3]=1473, y[7]=1089
# 59         FFT Combine (depth 1)          y = [18, 47873, 62461, 1473, 65531, 15106, 3068, 1089]
# 60         FFT Depth 0                    k=0, omega_k=1, t=18, y[0]=54, y[8]=18
# 61         FFT Depth 0                    k=1, omega_k=64, t=49170, y[1]=34182, y[9]=1379
# 62         FFT Depth 0                    k=2, omega_k=4096, t=49345, y[2]=47803, y[10]=14650
# 63         FFT Depth 0                    k=3, omega_k=65533, t=59645, y[3]=25809, y[11]=37593
# 64         FFT Depth 0                    k=4, omega_k=65281, t=1536, y[4]=1532, y[12]=63997
# 65         FFT Depth 0                    k=5, omega_k=49153, t=36545, y[5]=45911, y[13]=38358
# 66         FFT Depth 0                    k=6, omega_k=16, t=49088, y[6]=50618, y[14]=17979
# 67         FFT Depth 0                    k=7, omega_k=1024, t=1007, y[7]=40485, y[15]=38471
# 68         FFT Combine (depth 0)          y = [54, 34182, 47803, 25809, 1532, 45911, 50618, 40485, 18, 1379, 14650, 37593, 63997, 38358, 17979, 38471]
# 69         FFT Base (depth 4)             Input: [1]
# 70         FFT Base (depth 4)             Input: [0]
# 71         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=1, y[1]=1
# 72         FFT Combine (depth 3)          y = [1, 1]
# 73         FFT Base (depth 4)             Input: [14]
# 74         FFT Base (depth 4)             Input: [0]
# 75         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=14, y[1]=14
# 76         FFT Combine (depth 3)          y = [14, 14]
# 77         FFT Depth 2                    k=0, omega_k=1, t=14, y[0]=15, y[2]=65524
# 78         FFT Depth 2                    k=1, omega_k=65281, t=61953, y[1]=61954, y[3]=3585
# 79         FFT Combine (depth 2)          y = [15, 61954, 65524, 3585]
# 80         FFT Base (depth 4)             Input: [8]
# 81         FFT Base (depth 4)             Input: [0]
# 82         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=8, y[1]=8
# 83         FFT Combine (depth 3)          y = [8, 8]
# 84         FFT Base (depth 4)             Input: [10]
# 85         FFT Base (depth 4)             Input: [0]
# 86         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=10, y[1]=10
# 87         FFT Combine (depth 3)          y = [10, 10]
# 88         FFT Depth 2                    k=0, omega_k=1, t=10, y[0]=18, y[2]=65535
# 89         FFT Depth 2                    k=1, omega_k=65281, t=62977, y[1]=62985, y[3]=2568
# 90         FFT Combine (depth 2)          y = [18, 62985, 65535, 2568]
# 91         FFT Depth 1                    k=0, omega_k=1, t=18, y[0]=33, y[4]=65534
# 92         FFT Depth 1                    k=1, omega_k=4096, t=32928, y[1]=29345, y[5]=29026
# 93         FFT Depth 1                    k=2, omega_k=65281, t=512, y[2]=499, y[6]=65012
# 94         FFT Depth 1                    k=3, omega_k=16, t=41088, y[3]=44673, y[7]=28034
# 95         FFT Combine (depth 1)          y = [33, 29345, 499, 44673, 65534, 29026, 65012, 28034]
# 96         FFT Base (depth 4)             Input: [11]
# 97         FFT Base (depth 4)             Input: [0]
# 98         FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=11, y[1]=11
# 99         FFT Combine (depth 3)          y = [11, 11]
# 100        FFT Base (depth 4)             Input: [13]
# 101        FFT Base (depth 4)             Input: [0]
# 102        FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=13, y[1]=13
# 103        FFT Combine (depth 3)          y = [13, 13]
# 104        FFT Depth 2                    k=0, omega_k=1, t=13, y[0]=24, y[2]=65535
# 105        FFT Depth 2                    k=1, omega_k=65281, t=62209, y[1]=62220, y[3]=3339
# 106        FFT Combine (depth 2)          y = [24, 62220, 65535, 3339]
# 107        FFT Base (depth 4)             Input: [6]
# 108        FFT Base (depth 4)             Input: [0]
# 109        FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=6, y[1]=6
# 110        FFT Combine (depth 3)          y = [6, 6]
# 111        FFT Base (depth 4)             Input: [3]
# 112        FFT Base (depth 4)             Input: [0]
# 113        FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=3, y[1]=3
# 114        FFT Combine (depth 3)          y = [3, 3]
# 115        FFT Depth 2                    k=0, omega_k=1, t=3, y[0]=9, y[2]=3
# 116        FFT Depth 2                    k=1, omega_k=65281, t=64769, y[1]=64775, y[3]=774
# 117        FFT Combine (depth 2)          y = [9, 64775, 3, 774]
# 118        FFT Depth 1                    k=0, omega_k=1, t=9, y[0]=33, y[4]=15
# 119        FFT Depth 1                    k=1, omega_k=4096, t=24624, y[1]=21307, y[5]=37596
# 120        FFT Depth 1                    k=2, omega_k=65281, t=64769, y[2]=64767, y[6]=766
# 121        FFT Depth 1                    k=3, omega_k=16, t=12384, y[3]=15723, y[7]=56492
# 122        FFT Combine (depth 1)          y = [33, 21307, 64767, 15723, 15, 37596, 766, 56492]
# 123        FFT Depth 0                    k=0, omega_k=1, t=33, y[0]=66, y[8]=0
# 124        FFT Depth 0                    k=1, omega_k=64, t=52908, y[1]=16716, y[9]=41974
# 125        FFT Depth 0                    k=2, omega_k=4096, t=57393, y[2]=57892, y[10]=8643
# 126        FFT Depth 0                    k=3, omega_k=65533, t=2645, y[3]=47318, y[11]=42028
# 127        FFT Depth 0                    k=4, omega_k=65281, t=61697, y[4]=61694, y[12]=3837
# 128        FFT Depth 0                    k=5, omega_k=49153, t=9399, y[5]=38425, y[13]=19627
# 129        FFT Depth 0                    k=6, omega_k=16, t=12256, y[6]=11731, y[14]=52756
# 130        FFT Depth 0                    k=7, omega_k=1024, t=44174, y[7]=6671, y[15]=49397
# 131        FFT Combine (depth 0)          y = [66, 16716, 57892, 47318, 61694, 38425, 11731, 6671, 0, 41974, 8643, 42028, 3837, 19627, 52756, 49397]
# 132        poly_mul_mod                   Pointwise product: [3564, 34746, 45914, 13804, 10854, 5209, 34538, 62995, 0, 12975, 2466, 58145, 54887, 28947, 48660, 41135]
# 133        FFT Base (depth 4)             Input: [3564]
# 134        FFT Base (depth 4)             Input: [0]
# 135        FFT Depth 3                    k=0, omega_k=1, t=0, y[0]=3564, y[1]=3564
# 136        FFT Combine (depth 3)          y = [3564, 3564]
# 137        FFT Base (depth 4)             Input: [10854]
# 138        FFT Base (depth 4)             Input: [54887]
# 139        FFT Depth 3                    k=0, omega_k=1, t=54887, y[0]=204, y[1]=21504
# 140        FFT Combine (depth 3)          y = [204, 21504]
# 141        FFT Depth 2                    k=0, omega_k=1, t=204, y[0]=3768, y[2]=3360
# 142        FFT Depth 2                    k=1, omega_k=256, t=65453, y[1]=3480, y[3]=3648
# 143        FFT Combine (depth 2)          y = [3768, 3480, 3360, 3648]
# 144        FFT Base (depth 4)             Input: [45914]
# 145        FFT Base (depth 4)             Input: [2466]
# 146        FFT Depth 3                    k=0, omega_k=1, t=2466, y[0]=48380, y[1]=43448
# 147        FFT Combine (depth 3)          y = [48380, 43448]
# 148        FFT Base (depth 4)             Input: [34538]
# 149        FFT Base (depth 4)             Input: [48660]
# 150        FFT Depth 3                    k=0, omega_k=1, t=48660, y[0]=17661, y[1]=51415
# 151        FFT Combine (depth 3)          y = [17661, 51415]
# 152        FFT Depth 2                    k=0, omega_k=1, t=17661, y[0]=504, y[2]=30719
# 153        FFT Depth 2                    k=1, omega_k=256, t=54840, y[1]=32751, y[3]=54145
# 154        FFT Combine (depth 2)          y = [504, 32751, 30719, 54145]
# 155        FFT Depth 1                    k=0, omega_k=1, t=504, y[0]=4272, y[4]=3264
# 156        FFT Depth 1                    k=1, omega_k=65521, t=280, y[1]=3760, y[5]=3200
# 157        FFT Depth 1                    k=2, omega_k=256, t=65161, y[2]=2984, y[6]=3736
# 158        FFT Depth 1                    k=3, omega_k=61441, t=64825, y[3]=2936, y[7]=4360
# 159        FFT Combine (depth 1)          y = [4272, 3760, 2984, 2936, 3264, 3200, 3736, 4360]
# 160        FFT Base (depth 4)             Input: [34746]
# 161        FFT Base (depth 4)             Input: [12975]
# 162        FFT Depth 3                    k=0, omega_k=1, t=12975, y[0]=47721, y[1]=21771
# 163        FFT Combine (depth 3)          y = [47721, 21771]
# 164        FFT Base (depth 4)             Input: [5209]
# 165        FFT Base (depth 4)             Input: [28947]
# 166        FFT Depth 3                    k=0, omega_k=1, t=28947, y[0]=34156, y[1]=41799
# 167        FFT Combine (depth 3)          y = [34156, 41799]
# 168        FFT Depth 2                    k=0, omega_k=1, t=34156, y[0]=16340, y[2]=13565
# 169        FFT Depth 2                    k=1, omega_k=256, t=18013, y[1]=39784, y[3]=3758
# 170        FFT Combine (depth 2)          y = [16340, 39784, 13565, 3758]
# 171        FFT Base (depth 4)             Input: [13804]
# 172        FFT Base (depth 4)             Input: [58145]
# 173        FFT Depth 3                    k=0, omega_k=1, t=58145, y[0]=6412, y[1]=21196
# 174        FFT Combine (depth 3)          y = [6412, 21196]
# 175        FFT Base (depth 4)             Input: [62995]
# 176        FFT Base (depth 4)             Input: [41135]
# 177        FFT Depth 3                    k=0, omega_k=1, t=41135, y[0]=38593, y[1]=21860
# 178        FFT Combine (depth 3)          y = [38593, 21860]
# 179        FFT Depth 2                    k=0, omega_k=1, t=38593, y[0]=45005, y[2]=33356
# 180        FFT Depth 2                    k=1, omega_k=256, t=25515, y[1]=46711, y[3]=61218
# 181        FFT Combine (depth 2)          y = [45005, 46711, 33356, 61218]
# 182        FFT Depth 1                    k=0, omega_k=1, t=45005, y[0]=61345, y[4]=36872
# 183        FFT Depth 1                    k=1, omega_k=65521, t=39068, y[1]=13315, y[5]=716
# 184        FFT Depth 1                    k=2, omega_k=256, t=19326, y[2]=32891, y[6]=59776
# 185        FFT Depth 1                    k=3, omega_k=61441, t=61171, y[3]=64929, y[7]=8124
# 186        FFT Combine (depth 1)          y = [61345, 13315, 32891, 64929, 36872, 716, 59776, 8124]
# 187        FFT Depth 0                    k=0, omega_k=1, t=61345, y[0]=80, y[8]=8464
# 188        FFT Depth 0                    k=1, omega_k=64513, t=62673, y[1]=896, y[9]=6624
# 189        FFT Depth 0                    k=2, omega_k=65521, t=63577, y[2]=1024, y[10]=4944
# 190        FFT Depth 0                    k=3, omega_k=16384, t=152, y[3]=3088, y[11]=2784
# 191        FFT Depth 0                    k=4, omega_k=256, t=1904, y[4]=5168, y[12]=1360
# 192        FFT Depth 0                    k=5, omega_k=4, t=2864, y[5]=6064, y[13]=336
# 193        FFT Depth 0                    k=6, omega_k=61441, t=3736, y[6]=7472, y[14]=0
# 194        FFT Depth 0                    k=7, omega_k=65473, t=4360, y[7]=8720, y[15]=0
# 195        FFT Combine (depth 0)          y = [80, 896, 1024, 3088, 5168, 6064, 7472, 8720, 8464, 6624, 4944, 2784, 1360, 336, 0, 0]
# 196        poly_mul_mod                   Convolution result (raw): [5, 56, 64, 193, 323, 379, 467, 545, 529, 414, 309, 174, 85, 21, 0, 0]
# 197        schoenhage_strassen            Raw convolution coefficients: [5, 56, 64, 193, 323, 379, 467, 545, 529, 414, 309, 174, 85, 21, 0]
# 198        poly_to_int                    Normalized coeff: [5, 8, 3, 5, 15, 15, 11, 15, 4, 1, 1, 3, 1, 11, 1], final carry: 0
# 199        schoenhage_strassen            Final integer result: 121932631112635269
